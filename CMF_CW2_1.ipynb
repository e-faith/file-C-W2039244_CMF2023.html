# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as si
import yfinance as yf
import os

# %% [markdown]
# ### Historical Volatility

# %% [markdown]
# The histotical price of AMZN, Inc.

# %%
AMZN = yf.download("AMZN", start="2022-12-19", end="2023-12-19")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
S = AMZN['Adj Close'][-1]
print('The spot price is $', round(S,2), '.')
# Out:
# The spot price is $ 154.07 .

# %%
log_return = np.log(AMZN['Adj Close'] / AMZN['Adj Close'].shift(1))
vol_h = np.sqrt(252) * log_return.std()
print('The annualised volatility is', round(vol_h*100,2), '%')
# Out:
# The annualised volatility is 33.4 %

# %% [markdown]
# The Newton-Raphson Method to estimate impolied volatility

# %%
def newton_vol_call(S, K, T, C, r):
    
    #S: spot price
    #K: strike price
    #T: time to maturity
    #C: Call value
    #r: risk free rate
    #sigma: volatility of underlying asset
   
    MAX_ITERATIONS = 1000
    tolerance = 0.000001
    
    sigma = 0.25
    
    for i in range(0, MAX_ITERATIONS):
        d1 = (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
        d2 = (np.log(S / K) + (r - 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
        price = S * si.norm.cdf(d1, 0.0, 1.0) - K * np.exp(-r * T) * si.norm.cdf(d2, 0.0, 1.0)
        vega = S * np.sqrt(T) * si.norm.pdf(d1, 0.0, 1.0)

        diff = C - price

        if (abs(diff) < tolerance):
            return sigma
        else: 
            sigma = sigma + diff/vega
        
        # print(i,sigma,diff)
        
    return sigma

# %% [markdown]
# Download the AMZN option data.

# %%
AMZN = yf.Ticker("AMZN")
opt = AMZN.option_chain('2024-01-19')
opt.calls
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    AMZN240119C00045000 2023-12-18 19:49:38+00:00    45.0     109.67  108.45
# 1    AMZN240119C00050000 2023-12-15 16:32:00+00:00    50.0      99.41  103.50
# 2    AMZN240119C00052000 2023-12-15 15:51:06+00:00    52.0      98.00  101.50
# 3    AMZN240119C00053000 2023-12-14 16:19:03+00:00    53.0      95.50  100.50
# 4    AMZN240119C00054000 2023-10-10 16:30:01+00:00    54.0      77.38   86.80
# ..                   ...                       ...     ...        ...     ...
# 339  AMZN240119C05000000 2022-06-03 17:49:58+00:00  5000.0      37.09   33.05
# 340  AMZN240119C05100000 2022-06-03 14:41:34+00:00  5100.0      31.87   30.30
# 341  AMZN240119C05200000 2022-06-03 13:51:00+00:00  5200.0      34.20   27.75
# 342  AMZN240119C05300000 2022-06-02 13:36:26+00:00  5300.0      29.00   25.65
# 343  AMZN240119C05400000 2022-06-03 19:12:26+00:00  5400.0      26.00   23.60
#
#         ask    change  percentChange  volume  openInterest  impliedVolatility  \
# 0    109.15  0.000000       0.000000       1           316           1.998047
# 1    104.20  0.000000       0.000000       5          1953           1.875001
# 2    102.20  0.000000       0.000000       1          3296           1.813477
# 3    101.20  0.000000       0.000000       9          1761           1.783204
# 4     87.90  0.000000       0.000000     201          1401           0.000010
# ..      ...       ...            ...     ...           ...                ...
# 339   41.05 -1.979999      -5.067826       7           474           7.851319
# 340   38.05  0.930000       3.005819       2           108           7.704224
# 341   35.30  3.200001      10.322583       1           437           7.566163
# 342   32.95  0.000000       0.000000       1           698           7.450074
# 343   30.65 -3.850000     -12.897823      23          2045           7.333009
#
#      inTheMoney contractSize currency
# 0          True      REGULAR      USD
# 1          True      REGULAR      USD
# 2          True      REGULAR      USD
# 3          True      REGULAR      USD
# 4          True      REGULAR      USD
# ..          ...          ...      ...
# 339       False      REGULAR      USD
# 340       False      REGULAR      USD
# 341       False      REGULAR      USD
# 342       False      REGULAR      USD
# 343       False      REGULAR      USD
#
# [344 rows x 14 columns]

# %%
impvol = newton_vol_call(S, 165, 4/52, float(opt.calls.lastPrice[opt.calls.strike == 165.00]), 0.013675)
print('The implied volatility is', round(impvol*100,2) , '% for the one-month call with strike $ 165.00' )
# Out:
# The implied volatility is 25.47 % for the one-month call with strike $ 165.00
# C:\Users\ibiro\AppData\Local\Temp\ipykernel_19816\2574922674.py:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   impvol = newton_vol_call(S, 165, 4/52, float(opt.calls.lastPrice[opt.calls.strike == 165.00]), 0.013675)
